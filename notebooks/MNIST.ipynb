# %%
import sys
sys.path.insert(0, '..')
from dataset_collection.image import MNIST


from matplotlib import pyplot as plt
# %matplotlib inline

# %%
DATASET_ROOT = '../../data' 
ds = MNIST(DATASET_ROOT)

# %%
val_images, val_labels = ds.get_val_dataset()
train_images, train_labels = ds.get_train_dataset()

# %%
for image, label in zip(train_images[:10], train_labels[:10]):
    plt.figure()
    plt.imshow(image)
    plt.title(label)

# %%
for image, label in zip(val_images[:10], val_labels[:10]):
    plt.figure()
    plt.imshow(image)
    plt.title(label)
